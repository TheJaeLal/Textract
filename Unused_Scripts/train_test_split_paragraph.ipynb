# %%
import os
import random
import shutil

# %%
input_dir_path = '/home/ubuntu/Scaled_Paragraph_Images'
train_path = '/home/ubuntu/train'
test_path = '/home/ubuntu/test'

# %%
image_names = [fname for fname in os.listdir(input_dir_path) if fname.lower().endswith(".png") or fname.lower().endswith(".jpg")]

# %%
image_names[0]
# Out:
# 'd04-089.png'

# %%
random.shuffle(image_names)

# %%
image_names[0]
# Out:
# 'k04-136.png'

# %%
len(image_names)
# Out:
# 1539

# %%
num_test = 139

# %%
test_images = image_names[:num_test]
train_images = image_names[num_test:]

# %%
len(test_images)
# Out:
# 139

# %%
len(train_images)
# Out:
# 1400

# %%
#move train_images to train folder and 
#test_images to test folder

# %%
[shutil.move(os.path.join(input_dir_path,image),
             os.path.join(train_path,image))
    for image in train_images]
# Out:
# ['/home/ubuntu/train/g06-026h.png',
#  '/home/ubuntu/train/b04-154.png',
#  '/home/ubuntu/train/b01-062.png',
#  '/home/ubuntu/train/g05-087.png',
#  '/home/ubuntu/train/p03-087.png',
#  '/home/ubuntu/train/p03-029.png',
#  '/home/ubuntu/train/a05-069.png',
#  '/home/ubuntu/train/a05-125.png',
#  '/home/ubuntu/train/p01-168.png',
#  '/home/ubuntu/train/a05-053.png',
#  '/home/ubuntu/train/a02-024.png',
#  '/home/ubuntu/train/a01-058.png',
#  '/home/ubuntu/train/g06-018o.png',
#  '/home/ubuntu/train/g07-038.png',
#  '/home/ubuntu/train/c02-059.png',
#  '/home/ubuntu/train/p06-058.png',
#  '/home/ubuntu/train/n06-169.png',
#  '/home/ubuntu/train/c03-084a.png',
#  '/home/ubuntu/train/p02-008.png',
#  '/home/ubuntu/train/a04-066.png',
#  '/home/ubuntu/train/h01-004.png',
#  '/home/ubuntu/train/a03-040.png',
#  '/home/ubuntu/train/n02-037.png',
#  '/home/ubuntu/train/g07-007a.png',
#  '/home/ubuntu/train/h04-021.png',
#  '/home/ubuntu/train/h07-069.png',
# ...

# %%
[shutil.move(os.path.join(input_dir_path,image),
             os.path.join(test_path,image))
    for image in test_images]
# Out:
# ['/home/ubuntu/test/k04-136.png',
#  '/home/ubuntu/test/p06-088.png',
#  '/home/ubuntu/test/r06-137.png',
#  '/home/ubuntu/test/k04-039.png',
#  '/home/ubuntu/test/g06-047g.png',
#  '/home/ubuntu/test/d04-131.png',
#  '/home/ubuntu/test/n03-064.png',
#  '/home/ubuntu/test/g06-047a.png',
#  '/home/ubuntu/test/j01-066.png',
#  '/home/ubuntu/test/j04-115.png',
#  '/home/ubuntu/test/c03-000d.png',
#  '/home/ubuntu/test/b06-049.png',
#  '/home/ubuntu/test/c02-022.png',
#  '/home/ubuntu/test/a04-010.png',
#  '/home/ubuntu/test/r06-066.png',
#  '/home/ubuntu/test/g02-073.png',
#  '/home/ubuntu/test/a06-157.png',
#  '/home/ubuntu/test/k04-156.png',
#  '/home/ubuntu/test/m03-013.png',
#  '/home/ubuntu/test/a01-063u.png',
#  '/home/ubuntu/test/a01-030.png',
#  '/home/ubuntu/test/d01-123.png',
#  '/home/ubuntu/test/n06-111.png',
#  '/home/ubuntu/test/n06-201.png',
#  '/home/ubuntu/test/b04-034.png',
#  '/home/ubuntu/test/l04-174.png',
#  '/home/ubuntu/test/l03-008.png',
# ...
