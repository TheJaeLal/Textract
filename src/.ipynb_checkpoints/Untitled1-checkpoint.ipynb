# %%
import joblib
import numpy as np

# %%
s = joblib.load("unique_in_image")

# %%
s.shape
# Out:
# (13623,)

# %%
list(s)[len(s)-100:]
# Out:
# [255.49049133237361,
#  255.4926847691128,
#  255.54135674972596,
#  255.54164767225237,
#  255.56754070993185,
#  255.59624602577676,
#  255.61862376067756,
#  255.64204400372441,
#  255.65549512532658,
#  255.67727538180714,
#  255.68790718969842,
#  255.69240133572981,
#  255.69359923130318,
#  255.69673073350128,
#  255.69796370559726,
#  255.69826093469504,
#  255.70062724502037,
#  255.70283924220573,
#  255.72309275916535,
#  255.72594757665297,
#  255.72633482244484,
#  255.72830088660248,
#  255.73231020620477,
#  255.734045815532,
#  255.73749050955524,
#  255.74243282573357,
#  255.74818405984644,
#  255.76290708162531,
#  255.82115089546809,
#  255.85882607849885,
#  255.88971310158959,
#  255.93024785091379,
#  255.97360323621922,
#  255.97905147045608,
#  255.98989448575222,
#  255.99217093885144,
#  255.99363357519434,
#  256.01472860722015,
#  256.08462199285265,
#  256.12188841343055,
#  256.14499158449144,
#  256.19947856144694,
#  256.21755409953431,
# ...

# %%
from collections import Counter
