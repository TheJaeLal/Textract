# %%
import joblib

# %%
out = joblib.load('conv_0.dmp')

# %%
out
# Out:
# array([[[[ 1.38758290e+00,  5.01799047e-01, -5.88331707e-02, ...,
#           -1.75687388e-01, -2.72259992e-02, -1.03776507e-01],
#          [ 1.38758314e+00,  5.01800120e-01, -5.88331781e-02, ...,
#           -2.00998977e-01, -2.72259992e-02, -1.09296098e-01],
#          [ 1.38758314e+00,  5.01800120e-01, -5.88331781e-02, ...,
#           -2.00999171e-01, -2.72260252e-02, -1.09296106e-01],
#          ...,
#          [ 1.38758314e+00,  5.01800120e-01, -5.88331781e-02, ...,
#           -2.00999171e-01, -2.72260252e-02, -1.09296106e-01],
#          [ 1.38758314e+00,  5.01800120e-01, -5.88331819e-02, ...,
#           -2.00999171e-01, -2.72260252e-02, -1.09296106e-01],
#          [ 1.06538963e+00,  4.74995852e-01, -4.98640649e-02, ...,
#           -1.87547039e-02,  6.51244402e-01, -4.31166068e-02]],
#
#         [[ 2.89020032e-01,  1.21170934e-02,  1.20624232e+00, ...,
#            9.83526349e-01, -2.09660493e-02,  1.16741173e-01],
# ...

# %%
out2 = joblib.load('conv_1.dmp')

# %%
out2
# Out:
# array([[[[ 1.38758433e+00,  5.01798809e-01, -5.88331297e-02, ...,
#           -1.75687537e-01, -2.72259619e-02, -1.03776492e-01],
#          [ 1.38758349e+00,  5.01799464e-01, -5.88331036e-02, ...,
#           -2.00998664e-01, -2.72259861e-02, -1.09296061e-01],
#          [ 1.38758326e+00,  5.01800120e-01, -5.88331409e-02, ...,
#           -2.00998664e-01, -2.72259954e-02, -1.09296106e-01],
#          ...,
#          [ 1.38758314e+00,  5.01800120e-01, -5.88331781e-02, ...,
#           -2.00999171e-01, -2.72260252e-02, -1.09296106e-01],
#          [ 1.38758314e+00,  5.01800120e-01, -5.88331819e-02, ...,
#           -2.00999171e-01, -2.72260252e-02, -1.09296106e-01],
#          [ 1.06538963e+00,  4.74995852e-01, -4.98640649e-02, ...,
#           -1.87547039e-02,  6.51244402e-01, -4.31166068e-02]],
#
#         [[ 1.69200599e-01,  1.76881528e+00,  1.66576564e+00, ...,
#            2.27658248e+00, -6.46353364e-02, -1.03992693e-01],
# ...

# %%
out == out2
# Out:
# array([[[[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False,  True, False, ..., False, False,  True],
#          ...,
#          [ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True]],
#
#         [[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True]],
#
#         [[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
# ...
